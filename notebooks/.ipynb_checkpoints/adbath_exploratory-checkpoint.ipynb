# %%
import matplotlib.pyplot as plt
import pandas as pd
import configparser
from psycopg2 import connect
import psycopg2.sql as pg
import pandas.io.sql as pandasql
from sqlalchemy import create_engine
import io
import datetime 
import numpy 

CONFIG = configparser.ConfigParser()
CONFIG.read(r'C:\Users\alouis2\Documents\Python Scripts\db.cfg')
dbset = CONFIG['DBSETTINGS']
con = connect(**dbset)

# %% [markdown]
# ## Vehicles
# ***

# %%
string = '''WITH vols as (SELECT datetime_bin, sum(volume) as volume
                FROM miovision.volumes_15min
                    WHERE classification_uid in (1,4, 5)
                    AND intersection_uid = 1
                    AND (leg = 'E' AND dir = 'EB')
                    AND extract(dow from datetime_bin) in (1,2,3,4,5)
                GROUP BY datetime_bin
                ORDER BY datetime_bin)

SELECT cast(extract(dow from datetime_bin) as int) as day,  
"time"(datetime_bin) as timestamp, 
avg(volume) as volume
from vols
group by day, timestamp
order by day, timestamp;'''

df = pandasql.read_sql(pg.SQL(string), con)

df.head(10)
# Out:
#    day timestamp  volume
# 0    1  00:00:00    43.5
# 1    1  00:15:00    40.0
# 2    1  00:30:00    30.5
# 3    1  00:45:00    29.5
# 4    1  01:00:00    27.5
# 5    1  01:15:00    18.0
# 6    1  01:30:00    19.5
# 7    1  01:45:00    19.5
# 8    1  02:00:00    17.0
# 9    1  02:15:00    18.0

# %%
df.pivot_table(index=['timestamp'], columns=['day'], values=['volume']).plot(rot = 45, figsize = (15, 10))
mean = pd.DataFrame(df.groupby('timestamp').mean()).reset_index()
std = pd.DataFrame(df.groupby('timestamp').std()).reset_index()
upper = pd.DataFrame(mean['volume'].add(1.96*std['volume']).apply(round, 1))
upper['timestamp'] = df['timestamp']
lower['timestamp'] = df['timestamp']
lower = pd.DataFrame(mean['volume'].add(-1.96*std['volume']).apply(round, 1))
times = pd.DataFrame(mean['timestamp'])

plt.plot(times, upper['volume'], linewidth = 1.5, color = 'blue', label = 'Upper Bound')
plt.plot(times, lower['volume'], linewidth = 1.5, color = 'blue', label = 'Lower Bound')
l = plt.legend()
l.get_texts()[0].set_text('Monday')
l.get_texts()[1].set_text('Tuesday')
l.get_texts()[2].set_text('Wednesday')
l.get_texts()[3].set_text('Thursday')
l.get_texts()[4].set_text('Friday')
#l.get_texts()[5].set_text('Upper/Lower Bound')
labels = [datetime.time(0, 0), datetime.time(2, 0), datetime.time(4, 0),\
          datetime.time(6, 0), datetime.time(8, 0), datetime.time(10, 0),\
          datetime.time(12, 0), datetime.time(14, 0), datetime.time(16, 0),\
          datetime.time(18, 0), datetime.time(20, 0), datetime.time(22, 0)]

plt.title("Adelaide and Bathurst Volumes- Eastbound")
plt.xlabel("Timestamp")
plt.xticks(labels)
plt.ylabel("Volume")
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 15}
plt.rc('font', **font)

plt.plot(times, mean['volume'], linewidth = 3, color = 'black')

#for i in range(len(times.values)):
#    plt.fill_between(times.values[i], lower.values[i], upper.values[i], color = 'red',alpha = 0.5,linewidth = 8)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\alouis2\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\font_manager.py:1316: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
piv = df.pivot_table(index=['timestamp'], columns=['day'], values=['volume']).reset_index()
anomalous = []
for i in range(1, 6):
    for j in range(len(piv)): 
        if piv['volume'][i].loc[j,] > upper['volume'].loc[j,]: 
            anomalous.append([piv['volume'][i].loc[j,], i, piv['timestamp'].loc[j,], 'Vehicle'])
        if piv['volume'][i].loc[j,] < lower['volume'].loc[j,]:
            anomalous.append([piv['volume'][i].loc[j,], i, piv['timestamp'].loc[j,], 'Vehicle'])

# %%
anomalous
# Out:
# []

# %% [markdown]
# ## Bikes
# ***

# %%
string2 = '''WITH vols as (SELECT datetime_bin, sum(volume) as volume
                FROM miovision.volumes_15min
                    WHERE classification_uid in (2, 7)
                    AND intersection_uid = 1
                    AND (leg = 'E' AND dir = 'EB')
                    AND extract(dow from datetime_bin) in (1,2,3,4,5)
                GROUP BY datetime_bin
                ORDER BY datetime_bin)

                SELECT cast(extract(dow from datetime_bin) as int) as day,  
                "time"(datetime_bin) as timestamp, 
                avg(volume) as volume
                from vols
                group by day, timestamp
                order by day, timestamp'''

df2 = pandasql.read_sql(pg.SQL(string2), con)

df2.head(10)
# Out:
#    day timestamp  volume
# 0    1  00:00:00     1.0
# 1    1  00:15:00     1.0
# 2    1  00:30:00     0.0
# 3    1  00:45:00     0.5
# 4    1  01:00:00     0.5
# 5    1  01:15:00     0.0
# 6    1  01:30:00     0.0
# 7    1  01:45:00     0.0
# 8    1  02:00:00     0.0
# 9    1  02:15:00     0.0

# %%
df2.pivot_table(index=['timestamp'], columns=['day'], values=['volume']).plot(rot = 45, figsize = (15, 10))
mean = pd.DataFrame(df2.groupby('timestamp').mean()).reset_index()
std = pd.DataFrame(df2.groupby('timestamp').std()).reset_index()
upper = pd.DataFrame(mean['volume'].add(1.96*std['volume']).apply(round, 1))
upper['timestamp'] = df2['timestamp']
lower['timestamp'] = df2['timestamp']
lower = pd.DataFrame(mean['volume'].add(-1.96*std['volume']).apply(round, 1))
times = pd.DataFrame(mean['timestamp'])

plt.plot(times, upper['volume'], linewidth = 1.5, color = 'blue', label = 'Upper Bound')
plt.plot(times, lower['volume'], linewidth = 1.5, color = 'blue', label = 'Lower Bound')
l = plt.legend()
l.get_texts()[0].set_text('Monday')
l.get_texts()[1].set_text('Tuesday')
l.get_texts()[2].set_text('Wednesday')
l.get_texts()[3].set_text('Thursday')
l.get_texts()[4].set_text('Friday')
#l.get_texts()[5].set_text('Upper/Lower Bound')


plt.title("Adelaide and Bathurst Bike Volumes- Eastbound")
plt.xlabel("Timestamp")
plt.xticks(labels)
plt.ylabel("Volume")
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 15}
plt.rc('font', **font)

plt.plot(times, mean['volume'], linewidth = 3, color = 'black')
# Out:
# C:\Users\alouis2\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\font_manager.py:1316: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
piv = df2.pivot_table(index=['timestamp'], columns=['day'], values=['volume']).reset_index()

for i in range(1, 6):
    for j in range(len(piv)): 
        if piv['volume'][i].loc[j,] > upper['volume'].loc[j,]: 
            anomalous.append([piv['volume'][i].loc[j,], i, piv['timestamp'].loc[j,],'Bike'])
        if piv['volume'][i].loc[j,] < lower['volume'].loc[j,]:
            anomalous.append([piv['volume'][i].loc[j,], i, piv['timestamp'].loc[j,],'Bike'])

# %%
anomalous
# Out:
# [[0.75, 2, datetime.time(6, 0), 'Bike'],
#  [0.66666666666666663, 4, datetime.time(0, 0), 'Bike'],
#  [0.33333333333333331, 4, datetime.time(1, 30), 'Bike'],
#  [0.33333333333333331, 4, datetime.time(2, 30), 'Bike'],
#  [0.33333333333333331, 4, datetime.time(3, 30), 'Bike'],
#  [0.40000000000000002, 5, datetime.time(1, 15), 'Bike'],
#  [0.20000000000000001, 5, datetime.time(1, 30), 'Bike'],
#  [0.40000000000000002, 5, datetime.time(2, 15), 'Bike']]

# %% [markdown]
# ## Peds
# ***

# %%
string3 = '''WITH vols as (SELECT datetime_bin, sum(volume) as volume
                FROM miovision.volumes_15min
                    WHERE classification_uid = 6
                    AND intersection_uid = 1
                    AND (leg = 'E' AND dir = 'NB')
                    AND extract(dow from datetime_bin) in (1,2,3,4,5)
                GROUP BY datetime_bin
                ORDER BY datetime_bin)

            SELECT cast(extract(dow from datetime_bin) as int) as day,  
            "time"(datetime_bin) as timestamp, 
            avg(volume) as volume
            from vols
            group by day, timestamp
            order by day, timestamp;'''

df3 = pandasql.read_sql(pg.SQL(string3), con)

df3.head(10)
# Out:
#    day timestamp  volume
# 0    1  00:00:00     2.0
# 1    1  00:15:00     4.0
# 2    1  00:30:00     2.0
# 3    1  00:45:00     3.0
# 4    1  01:00:00     1.5
# 5    1  01:15:00     1.5
# 6    1  01:30:00     4.0
# 7    1  01:45:00     1.5
# 8    1  02:00:00     7.5
# 9    1  02:15:00     1.5

# %%
df3.pivot_table(index=['timestamp'], columns=['day'], values=['volume']).plot(rot = 45, figsize = (15, 10))
mean = pd.DataFrame(df3.groupby('timestamp').mean()).reset_index()
std = pd.DataFrame(df3.groupby('timestamp').std()).reset_index()
upper = pd.DataFrame(mean['volume'].add(1.96*std['volume']).apply(round, 1))
upper['timestamp'] = df3['timestamp']
lower['timestamp'] = df3['timestamp']
lower = pd.DataFrame(mean['volume'].add(-1.96*std['volume']).apply(round, 1))
times = pd.DataFrame(mean['timestamp'])

plt.plot(times, upper['volume'], linewidth = 1.5, color = 'blue', label = 'Upper Bound')
plt.plot(times, lower['volume'], linewidth = 1.5, color = 'blue', label = 'Lower Bound')
l = plt.legend()
l.get_texts()[0].set_text('Monday')
l.get_texts()[1].set_text('Tuesday')
l.get_texts()[2].set_text('Wednesday')
l.get_texts()[3].set_text('Thursday')
l.get_texts()[4].set_text('Friday')

plt.title("Adelaide and Bathurst Ped Volumes- East Leg, Northbound")
plt.xlabel("Timestamp")
plt.xticks(labels)
plt.ylabel("Volume")
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 15}
plt.rc('font', **font)

plt.plot(times, mean['volume'], linewidth = 3, color = 'black')
# Out:
# C:\Users\alouis2\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\font_manager.py:1316: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
piv = df3.pivot_table(index=['timestamp'], columns=['day'], values=['volume']).reset_index()


for i in range(1, 6):
    for j in range(len(piv)): 
        if piv['volume'][i].loc[j,] > upper['volume'].loc[j,]: 
            anomalous.append([piv['volume'][i].loc[j,], i, piv['timestamp'].loc[j,], 'Ped'])
        if piv['volume'][i].loc[j,] < lower['volume'].loc[j,]:
            anomalous.append([piv['volume'][i].loc[j,], i, piv['timestamp'].loc[j,], 'Ped'])

# %%
anomalous
# Out:
# [[0.75, 2, datetime.time(6, 0), 'Bike'],
#  [0.66666666666666663, 4, datetime.time(0, 0), 'Bike'],
#  [0.33333333333333331, 4, datetime.time(1, 30), 'Bike'],
#  [0.33333333333333331, 4, datetime.time(2, 30), 'Bike'],
#  [0.33333333333333331, 4, datetime.time(3, 30), 'Bike'],
#  [0.40000000000000002, 5, datetime.time(1, 15), 'Bike'],
#  [0.20000000000000001, 5, datetime.time(1, 30), 'Bike'],
#  [0.40000000000000002, 5, datetime.time(2, 15), 'Bike']]

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import matplotlib.pyplot as plt
import numpy as np

from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets.samples_generator import make_blobs
from sklearn.preprocessing import StandardScaler

centers = [[1, 1], [-1, -1], [1, -1]]
X, labels_true = make_blobs(n_samples=750, centers=centers, cluster_std=0.4,
                            random_state=0)

X = StandardScaler().fit_transform(X)
